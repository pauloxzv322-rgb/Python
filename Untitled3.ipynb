# %% [markdown]
# Questao 1

# %%
nome = "Paulo Henrique"
idade = 25
profissao = "Desenvolvedor"
print("Seu nome é:",nome)
print("Sua idade é:",idade)
print("Sua profissão é:",profissao)
# Out:
# Seu nome é: Paulo Henrique
# Sua idade é: 25
# Sua profissão é: Desenvolvedor

# %% [markdown]
# Questão 2

# %%
produto = "Notebook"
marca = "Dell"
preço = 4500.00
print("produto:" , produto)
print("marca:" , marca)
print(f"preço R$ {preco:.2f}")
# Out:
# produto: Notebook
# marca: Dell
# preço R$ 4500.00

# %% [markdown]
# Questão 3

# %%
num1 = 12
num2 = 6
soma = (num1 + num2)
subtracao = (num1 - num2)
multiplicacao = (num1 * num2)
divisao = (num1 / num2)
print("Soma:",soma)
print("Subtração:",subtracao)
print("Multiplicação:",multiplicacao)
print("Divisão:",divisao)
# Out:
# Soma: 18
# Subtração: 6
# Multiplicação: 72
# Divisão: 2.0

# %% [markdown]
# Questão 4

# %%
num1 = 7
num2 = 2
soma = (num1 + num2)
subtracao = (num1 - num2)
multiplicacao = (num1 * num2)
divisao = (num1 / num2)
potencia = (num1 ** num2)
print("Soma:",soma)
print("Subtração:",subtracao)
print("Multiplicação:",multiplicacao)
print("Divisão:",divisao)
print("potência:",potencia)
# Out:
# Soma: 9
# Subtração: 5
# Multiplicação: 14
# Divisão: 3.5
# potência: 49

# %% [markdown]
# Questão 5

# %%
num1 = 15
num2 = 5
soma = (num1 + num2)
subtracao = (num1 - num2)
multiplicacao = (num1 * num2)
divisao = (num1 / num2)
potencia = (num1 ** num2)
print("Soma:",soma)
print("Subtração:",subtracao)
print("Multiplicação:",multiplicacao)
print("Divisão:",divisao)
print("potência:",potencia)
# Out:
# 20
# Subtração: 10
# Multiplicação: 75
# Divisão: 3.0
# potência: 759375

# %% [markdown]
# Questao 6

# %%
materias = "portugues,matematica,artes"
notas = "10,8,9"
aluno = "Paulo Henrique 29 anos python"
print("Materias:",materias)
print("Notas:",notas)
print("Informações do aluno:",aluno)
# Out:
# Materias: portugues,matematica,artes
# Notas: 10,8,9
# Informações do aluno: Paulo Henrique 29 anos python

# %% [markdown]
# Questão 7

# %%
acessorios = "capo,volante,roda"
especificacoes = "potência 120 cavalos,tanque 40 l"
carro = "gol g6 2023"
print("Acessórios:",acessorios)
print("Especificações:",especificacoes)
print("Informações do carro:",carro)
# Out:
# Acessórios: capo,volante,roda
# Especificações: potência 120 cavalos,tanque 40 l
# Informações do carro: gol g6 2023
